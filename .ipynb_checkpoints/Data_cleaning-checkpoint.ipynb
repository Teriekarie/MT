# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
# Load the dataset
file_path = "C:/Users/terre/Downloads/Uber Onboarding Information  - Copy of Form responses 1 (6).csv"
data = pd.read_csv(file_path)

# %%
# Display the first few rows of the dataset to understand its structure
data.head()
# Out:
#          Date              Names  Driver Phone number   City Type of partner  \
# 0  31/08/2020   ADEKUNLE KEHINDE         8.032372e+09  Lagos   Vehicle owner
# 1  01/09/2020        OSITA OLISA         8.149014e+09  Lagos   Vehicle owner
# 2  02/09/2020      ENOCK KOOMSOM         7.011869e+09  Lagos   Vehicle owner
# 3  02/09/2020   JOSEPH SALVATION         7.045576e+09  Lagos   Vehicle owner
# 4  03/09/2020  MOHAMMED SULEIMAN         8.035376e+09  Lagos   Vehicle owner
#
#   Onboarder         Referrer   Month              Status          Comment  \
# 0     Slack            Slack  Aug-20  Account not active  Rewards expired
# 1     Slack            Slack  Sep-20      Account active  Payment stopped
# 2       NaN   Auto solutions  Sep-20  Account not active  Rewards expired
# 3    Center    Total Asokoro  Sep-20     Invalid account  Inavlid Account
# 4    Center  Nationwide Ogba  Sep-20      Account active   Manual payment
#
#   First Trip Bonus Data Payment Status
# 0        NaN   NaN  NaN            NaN
# 1        NaN   NaN  NaN            NaN
# 2        NaN   NaN  NaN            NaN
# 3        NaN   NaN  NaN            NaN
# 4        NaN   NaN  NaN            NaN

# %%
# Display the DataFrame size and data types
print("Data size (rows, columns):", data.shape)
print("\nData types and non-null counts:\n")
print(data.info())
# Out:
# Data size (rows, columns): (2487, 14)
#
# Data types and non-null counts:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2487 entries, 0 to 2486
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 2367 non-null   object
#  1   Names                2368 non-null   object
#  2   Driver Phone number  2368 non-null   float64
#  3   City                 2368 non-null   object
#  4   Type of partner      2366 non-null   object
#  5   Onboarder            2272 non-null   object
#  6   Referrer             2280 non-null   object
#  7   Month                2486 non-null   object
#  8   Status               2366 non-null   object
#  9   Comment              2366 non-null   object
#  10  First Trip           124 non-null    object
#  11  Bonus                142 non-null    object
#  12  Data                 113 non-null    object
#  13  Payment Status       119 non-null    object
# dtypes: float64(1), object(13)
# memory usage: 272.1+ KB
# None

# %%
# Remove unnecessary columns
df = data.drop(columns=["Driver Phone number", "Names", "First Trip", "Bonus", "Data", "Payment Status"])

# %%
df.head()
# Out:
#          Date   City Type of partner Onboarder         Referrer   Month  \
# 0  31/08/2020  Lagos   Vehicle owner     Slack            Slack  Aug-20
# 1  01/09/2020  Lagos   Vehicle owner     Slack            Slack  Sep-20
# 2  02/09/2020  Lagos   Vehicle owner       NaN   Auto solutions  Sep-20
# 3  02/09/2020  Lagos   Vehicle owner    Center    Total Asokoro  Sep-20
# 4  03/09/2020  Lagos   Vehicle owner    Center  Nationwide Ogba  Sep-20
#
#                Status          Comment
# 0  Account not active  Rewards expired
# 1      Account active  Payment stopped
# 2  Account not active  Rewards expired
# 3     Invalid account  Inavlid Account
# 4      Account active   Manual payment

# %%
# Standardize column names
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
# Convert the "date" column to datetime format
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     509         try:
# --> 510             values, tz = conversion.datetime_to_datetime64(arg)
#     511             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17352\589559903.py in <module>
#       1 # Convert the "date" column to datetime format
# ----> 2 df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1045                 result = arg.tz_localize(tz)
#    1046     elif isinstance(arg, ABCSeries):
# -> 1047         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1048         if not cache_array.empty:
#    1049             result = arg.map(cache_array)
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     195         unique_dates = unique(arg)
#     196         if len(unique_dates) < len(arg):
# --> 197             cache_dates = convert_listlike(unique_dates, format)
#     198             cache_array = Series(cache_dates, index=unique_dates)
#     199             # GH#39882 and GH#35888 in case of None and NaT we get duplicates
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     392
#     393     if format is not None:
# --> 394         res = _to_datetime_with_format(
#     395             arg, orig_arg, name, tz, format, exact, errors, infer_datetime_format
#     396         )
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     512             return DatetimeIndex._simple_new(dta, name=name)
#     513         except (ValueError, TypeError):
# --> 514             raise err
#     515
#     516
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     499
#     500         # fallback
# --> 501         res = _array_strptime_with_fallback(
#     502             arg, name, tz, fmt, exact, errors, infer_datetime_format
#     503         )
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _array_strptime_with_fallback(arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     435
#     436     try:
# --> 437         result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors)
#     438         if "%Z" in fmt or "%z" in fmt:
#     439             return _return_parsed_timezone_results(result, timezones, tz, name)
#
# ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: unconverted data remains: 2

# %%
# Fix incorrect years
df['date'] = df['date'].str.replace('20222', '2022')

# %%
# Strip whitespace from the "date" column
df['date'] = df['date'].str.strip()

# %%
# Check for missing values in each column
missing_values = df.isnull().sum()

# %%
# Display the number of missing values in each column
print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# date               120
# city               119
# type_of_partner    121
# onboarder          215
# referrer           207
# month                1
# status             121
# comment            121
# dtype: int64

# %%
# Drop rows with missing values in the 'date' column
df = df.dropna(subset=['date'])

# %%
# Fill missing values in the specified columns with 'N/A'
columns_to_fill_na = ['city', 'type_of_partner', 'onboarder', 'referrer', 'status', 'comment']
df[columns_to_fill_na] = df[columns_to_fill_na].fillna('N/A')

# %%
# Check for missing values in each column
missing_values = df.isnull().sum()

# %%
# Display the number of missing values in each column
print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# date               0
# city               0
# type_of_partner    0
# onboarder          0
# referrer           0
# month              1
# status             0
# comment            0
# dtype: int64

# %%
df.tail(150)
# Out:
#            date   city type_of_partner      onboarder referrer   month  \
# 2218  29/4/2024  Abuja   Vehicle owner   Juliet Autos    Agent  Apr-24
# 2219  29/4/2024  Abuja   Vehicle owner         Cornel    Agent  Apr-24
# 2220  30/4/2024  Abuja   Vehicle owner          Anjin    Agent  Apr-24
# 2221  30/4/2024  Abuja   Vehicle owner        Ibrahim    Agent  Apr-24
# 2222  30/4/2024  Abuja   Vehicle owner        Ibrahim    Agent  Apr-24
# ...         ...    ...             ...            ...      ...     ...
# 2363  12/7/2024  Abuja   Vehicle owner   Juliet Autos    Agent  Jul-24
# 2364  12/7/2024  Lagos   Vehicle owner  Auto solution    Agent  Jul-24
# 2365  12/7/2024  Abuja   Vehicle owner   Juliet Autos    Agent  Jul-24
# 2366  12/7/2024  Abuja   Vehicle owner           Ruth    Agent  Jul-24
# 2367  13/7/2024  Abuja   Vehicle owner           Ruth    Agent  Jul-24
#
#                   status         comment
# 2218      Account active  Uploading docs
# 2219      Account active     Not driving
# 2220      Account active  Trip completed
# 2221      Account active     Not driving
# 2222      Account active  Trip completed
# ...                  ...             ...
# 2363      Account active         Driving
# 2364      Account active     Not driving
# 2365      Account active         Driving
# 2366             Blocked         Blocked
# 2367  Account not active  Uploading docs
#
# [150 rows x 8 columns]

# %%
# Define function to get week number of the month
def week_of_month_1(date):
    first_day = date.replace(day=1)
    dom = date.day
    adjusted_dom = dom + first_day.weekday()
    return (date.day - 1) // 7 + 1

#Week Calculation: The week_of_month function calculates the week by determining the day of the month and then using integer division to find the week number.
#(date.day - 1) // 7 + 1 ensures that days 1-7 are week 1, days 8-14 are week 2, and so on.

# %%
# Apply the function to create a new 'new_week' column
df['new_week'] = df['date'].apply(week_of_month_1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3020\3136654035.py in <module>
#       1 # Apply the function to create a new 'new_week' column
# ----> 2 df['new_week'] = df['date'].apply(week_of_month_1)
#
# c:\Users\terre\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# c:\Users\terre\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# c:\Users\terre\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1141                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142                 # "Callable[[Any], Any]"
# -> 1143                 mapped = lib.map_infer(
#    1144                     values,
#    1145                     f,  # type: ignore[arg-type]
#
# c:\Users\terre\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp\ipykernel_3020\2830188202.py in week_of_month_1(date)
#       1 # Define function to get week number of the month
#       2 def week_of_month_1(date):
# ----> 3     first_day = date.replace(day=1)
#       4     dom = date.day
#       5     adjusted_dom = dom + first_day.weekday()
#
# TypeError: str.replace() takes no keyword arguments

# %%
# Move the 'new_week' column to be directly after the 'week' column
week_col_index = df.columns.get_loc('month')
new_cols = (df.columns[:week_col_index + 1].tolist() + 
            ['new_week'] + 
            df.columns[week_col_index + 1:-1].tolist())
df = df[new_cols]

# %%
df.tail(150)
# Out:
#            date                     names   city type_of_partner  \
# 2188 2024-04-16  Chidiebere Ezemoyi peter  Abuja   Vehicle owner
# 2189 2024-04-16        Jude duru Chukwudi  Abuja   Vehicle owner
# 2190 2024-04-16     Ugonna Bright Ugwuodo  Lagos   Vehicle owner
# 2191 2024-04-17                Kasim Sidi  Abuja   Vehicle owner
# 2192 2024-04-17             Ben Alli Ogar  Lagos   Vehicle owner
# ...         ...                       ...    ...             ...
# 2333 2024-06-14                Paul Idoko  Abuja   Vehicle owner
# 2334 2024-06-15              James Daniel  Abuja   Vehicle owner
# 2335 2024-06-20             Moses Adekoya  Lagos   Vehicle owner
# 2336 2024-06-21             Bitrus Timnan  Abuja   Vehicle owner
# 2337 2024-06-22               Alex Godwin  Abuja   Vehicle owner
#
#           onboarder referrer   month  new_week          status         comment
# 2188        Ibrahim    Agent  Apr-24         3  Account active     Not driving
# 2189        Ibrahim    Agent  Apr-24         3  Account active         Driving
# 2190  Auto solution    Agent  Apr-24         3  Account active         Driving
# 2191         Cornel    Agent  Apr-24         3  Account active     Not driving
# 2192  Auto solution    Agent  Apr-24         3  Account active  Uploading docs
# ...             ...      ...     ...       ...             ...             ...
# 2333   Juliet Autos    Agent  Jun-24         2  Account active     Not driving
# 2334   Juliet Autos    Agent  Jun-24         3  Account active     Not driving
# 2335  Auto solution    Agent  Jun-24         3  Account active     Not driving
# 2336           Ruth    Agent  Jun-24         3  Account active     Not driving
# 2337         Cornel    Agent  Jun-24         4  Account active     Not driving
#
# [150 rows x 10 columns]

# %%
# Save the cleaned dataset to a new CSV file
cleaned_file_path = 'cleaned_uber_onboarding_data.csv'
data_cleaned.to_csv(cleaned_file_path, index=False)
